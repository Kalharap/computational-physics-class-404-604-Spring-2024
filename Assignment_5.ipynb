# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt

g = 9.80
tend = (2*y[1])/g
h = 0.001
y = [0 ,10.]
t = 0

def f(t, y):
    f = np.zeros(2)
    f[0] = y[1]  # Velocity
    f[1] = -g      # Acceleration due to gravity
    return f

def eu(t, h, y):
    g = f(t, y)
    for i in range(2):
        y[i] = y[i] + (h * g[i])  # Euler method
    return y

xp = []
yp = []

while t < tend:
    if (t + h) > tend:
        h = tend - t
    y = eu(t, h, y)
    xp = np.append(xp, y[0])
    t = t + h


plt.plot(np.linspace(0, tend, len(xp)), xp)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.title('ball Motion with Euler Method')
plt.show()

# %%
g = 9.80
tend = (2*y[1])/g
h = 0.001
y = [0, 10.]
t = 0

def f(t, y):
    f = np.zeros(2)
    f[0] = y[1]  # Velocity
    f[1] = -g      # Acceleration due to gravity
    return f

def rk4(t, h, y, n):
    k1 = np.zeros(n)
    k2 = np.zeros(n)
    k3 = np.zeros(n)
    k4 = np.zeros(n)
    k1=h*f(t,y)
    k2=h*f(t+0.5*h,y+0.5*k1)
    k3=h*f(t+0.5*h,y+0.5*k2)      # please finish this line
    k4=h*f(t+h,y+k3)              # please finish this line
    y+=(k1+2*k2+2*k3+k4)/6   # please finish this line
    return y

tp=[]
xp=[]

while(t<tend):
    if((t+h)>tend):
        h=tend-t
    y = rk4(t,h,y,2)
    xp=np.append(xp,y[0])
    tp=np.append(tp,t)
    t = t+h

plt.plot(tp,xp)

plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.title('Particle Motion with Runge-Kutta Method')
plt.show()
